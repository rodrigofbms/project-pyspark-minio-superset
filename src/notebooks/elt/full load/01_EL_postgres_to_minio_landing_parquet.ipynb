# %% [markdown]
# # EL(Extract and Load) Postgres AdventureWorks to MinIO

# %% [markdown]
# ### Install python dotenv for get the environment variables

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Is important to avoid inconsistencies, the jupyer notebook container and apache spark container has the same pyspark version, in my case is 3.5.0

# %% [markdown]
# ### Print version from pyspark, Put the same version from your apache spark

# %%
import pyspark

print(pyspark.__version__)
# Out:
# 3.5.0

# %% [markdown]
# ## Imports from pyspark, files and log

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import date_format
import logging
from configurations import configurations as config_file # Import configurations.py from the configurations folder
from functions import functions as func_file # Import functions.py from the functions folder
from datetime import datetime

# Import for get the environment variables 
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Import environment variables

# %%
load_dotenv()

MINIO_CONTAINER=os.getenv("MINIO_CONTAINER")
MINIO_USER=os.getenv("MINIO_USER")
MINIO_PASSWORD=os.getenv("MINIO_PASSWORD")
POSTGRES_CONTAINER=os.getenv("POSTGRES_CONTAINER")
POSTGRES_USER=os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD=os.getenv("POSTGRES_PASSWORD")

# %% [markdown]
# ## Configuration from Spark

# %%
conf = SparkConf()

conf.setAppName("Extract and Load postgres adventureworks to minIO") # Spark application name, Usefull for logs
# Add the jars from hadoop-aws and aws-java-sdk-bundle is necessary for org.apache.hadoop.fs.s3a.S3AFileSystem,
# add the Postgresql JDBC jar is necessary for connect on database. Add the delta-spark is necessary for delta catalog, all this Jars is auto-download from spark
conf.set("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4,"
         "com.amazonaws:aws-java-sdk-bundle:1.12.767,"
         "org.postgresql:postgresql:42.7.2,"
         "io.delta:delta-spark_2.12:3.2.0")
conf.set("spark.hadoop.fs.s3a.endpoint",f"http://{MINIO_CONTAINER}:9000") # Container and Port from MinIO
conf.set("spark.hadoop.fs.s3a.access.key", MINIO_USER) # Login from MinIO
conf.set("spark.hadoop.fs.s3a.secret.key", MINIO_PASSWORD) # Password from MinIO
conf.set("spark.hadoop.fs.s3a.path.style.access", True) # Enforces the use of URLs as the format. Without this, Spark attempts to use the AWS standard (bucket.endpoint), which fails in MinIO
conf.set("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") # Talk to Hadoop/Spark to use new conector S3A
conf.set("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") # How to credentials are acess via config(access key + secret)
conf.set("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") # active extension from Delta Lake
conf.set("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") # Change the standard catalog from spark to Delta 
conf.set("hive.metastore.uris", "thrift://metastore:9083") # Connect to Hive Metastore external

spark = SparkSession.builder.config(conf=conf).getOrCreate()

# %% [markdown]
# ## Configuration to activate the logging

# %%
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# Logging the Start process from ingestion
logging.info("Starting ingestions from Postgres adventureworks to MinIO landing...")
# Out:
# 2026-05-07 00:36:57,440 - INFO - Starting ingestions from Postgres adventureworks to MinIO landing...

# %% [markdown]
# ## Reading each table from postges and writing on minIO landing

# %%
for table_name in config_file.tables_postgres_adventureworks.values():
    
    try:
        # convert the table name from postgres to name in minIO s3
        table_name_converted_to_s3 = func_file.convert_table_name(table_name)

        # Reading table in postgres via JDBC
        df_input_data = spark.read \
            .format("jdbc") \
            .option("url", f"jdbc:postgresql://{POSTGRES_CONTAINER}:5432/Adventureworks") \
            .option("dbtable", table_name) \
            .option("user", POSTGRES_USER) \
            .option("password", POSTGRES_PASSWORD) \
            .option("driver", "org.postgresql.Driver") \
            .load()

        # Landing path
        landing_path = config_file.data_lakehouse_path["landing"]
        output_table_path = f"{landing_path}{table_name_converted_to_s3}"

        # Logging the processing
        logging.info(f"processing table {table_name_converted_to_s3}")

        # Adding a new column date related the load data
        df_with_update_data = func_file.add_data_last_update(df_input_data)

        # modifing the postgres tables for add a new column "month_key" to create a partition on the minIO landing based on modifieddate column
        df_with_month_partition = df_with_update_data.withColumn("month_key", date_format(df_with_update_data["modifieddate"], "yyyy-MM"))
        
        # Writing the dataframe on minIO landing
        logging.info(f"Writing table {table_name_converted_to_s3}...")
        df_with_month_partition.write.format("parquet").mode("overwrite").partitionBy("month_key").save(output_table_path)
        
        # Logging the sucessfully process
        logging.info(f"Table {table_name_converted_to_s3} Sucessfully processed and saved in MinIO landing on: {output_table_path}")

    
    except Exception as e:
        # Logging the Error
         logging.error(f"Error processing table {table_name}: {str(e)}")

# Logging the Ingestion
logging.info(f"Ingestions to landing completed!")
# Out:
# 2026-05-07 00:37:00,344 - INFO - processing table sales_countryregioncurrency
# 2026-05-07 00:37:00,998 - INFO - Writing table sales_countryregioncurrency...
# 2026-05-07 00:37:38,298 - INFO - Table sales_countryregioncurrency Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_countryregioncurrency
# 2026-05-07 00:37:38,343 - INFO - processing table sales_creditcard
# 2026-05-07 00:37:38,374 - INFO - Writing table sales_creditcard...
# 2026-05-07 00:37:52,069 - INFO - Table sales_creditcard Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_creditcard
# 2026-05-07 00:37:52,101 - INFO - processing table sales_currency
# 2026-05-07 00:37:52,123 - INFO - Writing table sales_currency...
# 2026-05-07 00:37:52,784 - INFO - Table sales_currency Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_currency
# 2026-05-07 00:37:52,828 - INFO - processing table sales_currencyrate
# 2026-05-07 00:37:52,852 - INFO - Writing table sales_currencyrate...
# 2026-05-07 00:37:57,263 - INFO - Table sales_currencyrate Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_currencyrate
# 2026-05-07 00:37:57,309 - INFO - processing table sales_customer
# 2026-05-07 00:37:57,338 - INFO - Writing table sales_customer...
# 2026-05-07 00:37:58,164 - INFO - Table sales_customer Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_customer
# 2026-05-07 00:37:58,208 - INFO - processing table sales_personcreditcard
# 2026-05-07 00:37:58,237 - INFO - Writing table sales_personcreditcard...
# 2026-05-07 00:38:01,838 - INFO - Table sales_personcreditcard Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_personcreditcard
# 2026-05-07 00:38:01,869 - INFO - processing table sales_salesorderdetail
# 2026-05-07 00:38:01,895 - INFO - Writing table sales_salesorderdetail...
# 2026-05-07 00:38:06,368 - INFO - Table sales_salesorderdetail Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_salesorderdetail
# 2026-05-07 00:38:06,405 - INFO - processing table sales_salesorderheader
# 2026-05-07 00:38:06,440 - INFO - Writing table sales_salesorderheader...
# 2026-05-07 00:38:10,268 - INFO - Table sales_salesorderheader Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_salesorderheader
# 2026-05-07 00:38:10,294 - INFO - processing table sales_salesorderheadersalesreason
# 2026-05-07 00:38:10,319 - INFO - Writing table sales_salesorderheadersalesreason...
# 2026-05-07 00:38:13,326 - INFO - Table sales_salesorderheadersalesreason Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_salesorderheadersalesreason
# 2026-05-07 00:38:13,365 - INFO - processing table sales_salesperson
# 2026-05-07 00:38:13,393 - INFO - Writing table sales_salesperson...
# 2026-05-07 00:38:14,323 - INFO - Table sales_salesperson Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_salesperson
# 2026-05-07 00:38:14,356 - INFO - processing table sales_salespersonquotahistory
# 2026-05-07 00:38:14,373 - INFO - Writing table sales_salespersonquotahistory...
# 2026-05-07 00:38:15,708 - INFO - Table sales_salespersonquotahistory Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_salespersonquotahistory
# 2026-05-07 00:38:15,746 - INFO - processing table sales_salesreason
# 2026-05-07 00:38:15,773 - INFO - Writing table sales_salesreason...
# 2026-05-07 00:38:16,248 - INFO - Table sales_salesreason Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_salesreason
# 2026-05-07 00:38:16,288 - INFO - processing table sales_salestaxrate
# 2026-05-07 00:38:16,312 - INFO - Writing table sales_salestaxrate...
# 2026-05-07 00:38:16,788 - INFO - Table sales_salestaxrate Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_salestaxrate
# 2026-05-07 00:38:16,826 - INFO - processing table sales_salesterritory
# 2026-05-07 00:38:16,850 - INFO - Writing table sales_salesterritory...
# 2026-05-07 00:38:17,277 - INFO - Table sales_salesterritory Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_salesterritory
# 2026-05-07 00:38:17,309 - INFO - processing table sales_salesterritoryhistory
# 2026-05-07 00:38:17,333 - INFO - Writing table sales_salesterritoryhistory...
# 2026-05-07 00:38:18,085 - INFO - Table sales_salesterritoryhistory Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_salesterritoryhistory
# 2026-05-07 00:38:18,114 - INFO - processing table sales_shoppingcartitem
# 2026-05-07 00:38:18,134 - INFO - Writing table sales_shoppingcartitem...
# 2026-05-07 00:38:18,527 - INFO - Table sales_shoppingcartitem Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_shoppingcartitem
# 2026-05-07 00:38:18,557 - INFO - processing table sales_specialoffer
# 2026-05-07 00:38:18,578 - INFO - Writing table sales_specialoffer...
# 2026-05-07 00:38:19,383 - INFO - Table sales_specialoffer Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_specialoffer
# 2026-05-07 00:38:19,406 - INFO - processing table sales_specialofferproduct
# 2026-05-07 00:38:19,426 - INFO - Writing table sales_specialofferproduct...
# 2026-05-07 00:38:20,230 - INFO - Table sales_specialofferproduct Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_specialofferproduct
# 2026-05-07 00:38:20,252 - INFO - processing table sales_store
# 2026-05-07 00:38:20,271 - INFO - Writing table sales_store...
# 2026-05-07 00:38:20,676 - INFO - Table sales_store Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/sales_store
# 2026-05-07 00:38:20,712 - INFO - processing table humanresources_employee
# 2026-05-07 00:38:20,735 - INFO - Writing table humanresources_employee...
# 2026-05-07 00:38:21,253 - INFO - Table humanresources_employee Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/humanresources_employee
# 2026-05-07 00:38:21,281 - INFO - processing table humanresources_department
# 2026-05-07 00:38:21,297 - INFO - Writing table humanresources_department...
# 2026-05-07 00:38:21,677 - INFO - Table humanresources_department Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/humanresources_department
# 2026-05-07 00:38:21,700 - INFO - processing table person_countryregion
# 2026-05-07 00:38:21,717 - INFO - Writing table person_countryregion...
# 2026-05-07 00:38:22,073 - INFO - Table person_countryregion Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/person_countryregion
# 2026-05-07 00:38:22,100 - INFO - processing table person_person
# 2026-05-07 00:38:22,130 - INFO - Writing table person_person...
# 2026-05-07 00:38:27,026 - INFO - Table person_person Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/person_person
# 2026-05-07 00:38:27,053 - INFO - processing table person_stateprovince
# 2026-05-07 00:38:27,074 - INFO - Writing table person_stateprovince...
# 2026-05-07 00:38:27,595 - INFO - Table person_stateprovince Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/person_stateprovince
# 2026-05-07 00:38:27,625 - INFO - processing table person_address
# 2026-05-07 00:38:27,643 - INFO - Writing table person_address...
# 2026-05-07 00:38:32,307 - INFO - Table person_address Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/person_address
# 2026-05-07 00:38:32,337 - INFO - processing table purchasing_shipmethod
# 2026-05-07 00:38:32,357 - INFO - Writing table purchasing_shipmethod...
# 2026-05-07 00:38:32,751 - INFO - Table purchasing_shipmethod Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/purchasing_shipmethod
# 2026-05-07 00:38:32,786 - INFO - processing table production_product
# 2026-05-07 00:38:32,809 - INFO - Writing table production_product...
# 2026-05-07 00:38:33,282 - INFO - Table production_product Sucessfully processed and saved in MinIO landing on: s3a://landing/adventureworks/production_product
# 2026-05-07 00:38:33,283 - INFO - Ingestions to landing completed!

# %% [markdown]
# ## Stop session and clear cash from spark

# %%
spark.stop()
spark.catalog.clearCache()
