# %% [markdown]
# # Load minIO Landing to MinIO bronze (Incremental)

# %% [markdown]
# ### Install python dotenv for get the environment variables

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Imports libs, files and configure the absolute path

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, functions
from pyspark.sql.functions import date_format
import logging
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed

# Import for get the environment variables 
from dotenv import load_dotenv
import os
import sys
sys.path.append(os.path.abspath("../../")) # Used to reconfigure the absolut path. In this case, setting the absolut path to 2 folders back (notebooks/...) 
from configurations import configurations as config_file # Import configurations.py from the configurations folder
from functions import functions as func_file # Import functions.py from the functions folder

# %% [markdown]
# ## Load environment variables

# %%
load_dotenv()

MINIO_CONTAINER=os.getenv("MINIO_CONTAINER")
MINIO_USER=os.getenv("MINIO_USER")
MINIO_PASSWORD=os.getenv("MINIO_PASSWORD")
POSTGRES_CONTAINER=os.getenv("POSTGRES_CONTAINER")
POSTGRES_USER=os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD=os.getenv("POSTGRES_PASSWORD")

# %% [markdown]
# ## Spark configurations

# %%
def configure_spark():
    conf = SparkConf()
    
    conf.setAppName("Incremental load from MinIO landing to MinIO bronze") # Spark application name, Usefull for logs
    conf.set("spark.master", "spark://spark-master:7077") # set the Spark container to be distributed among the workers
    conf.set("spark.hadoop.fs.s3a.endpoint",f"http://{MINIO_CONTAINER}:9000") # Container and Port from MinIO
    conf.set("spark.hadoop.fs.s3a.access.key", MINIO_USER) # Login from MinIO
    conf.set("spark.hadoop.fs.s3a.secret.key", MINIO_PASSWORD) # Password from MinIO
    # Add the jars from hadoop-aws and aws-java-sdk-bundle is necessary for org.apache.hadoop.fs.s3a.S3AFileSystem,
    # add the Postgresql JDBC jar is necessary for connect on database. Add the delta-spark is necessary for delta catalog, all this Jars is auto-download from spark
    conf.set("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4,"
            "com.amazonaws:aws-java-sdk-bundle:1.12.367,"
            "org.postgresql:postgresql:42.7.2,"
            "io.delta:delta-spark_2.12:3.1.0" )
    conf.set("spark.hadoop.fs.s3a.path.style.access", True) # Enforces the use of URLs as the format. Without this, Spark attempts to use the AWS standard (bucket.endpoint), which fails in MinIO
    conf.set("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") # Talk to Hadoop/Spark to use new conector S3A
    conf.set("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") # How to credentials are acess via config(access key + secret)
    conf.set("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") # active extension from Delta Lake
    conf.set("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") # Change the standard catalog from spark to Delta 
    conf.set("hive.metastore.uris", "thrift://metastore:9083") # Connect to Hive Metastore external
    
    spark = SparkSession.builder.config(conf=conf).getOrCreate()
    return spark

# %% [markdown]
# ## Configuration the Logging and log the startup

# %%
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# %% [markdown]
# ## Creating a method to process each table when is called on method main

# %%
def process_table(spark, table_name, table_name_converted, input_table_path, output_table_path):

    try:
    
        # Logging the processing
        logging.info(f"processing table {table_name_converted}")
        
        # Getting max date value from minIO bronze in the modifieddate column. limit at 1 result and get this result on 1º row at max_modifieddate column
        df_max_modifieddate_bronze = spark.read.format("delta").load(output_table_path) \
            .select(functions.max("modifieddate").alias("max_modifieddate")).limit(1).collect()[0]["max_modifieddate"]

        # Getting max date value from minIO landing on parquet format in the modifieddate column.
        df_update_data_to_bronze = spark.read.format("parquet").load(input_table_path) \
        .filter(functions.col("modifieddate") > functions.lit(df_max_modifieddate_bronze))
        
        rows_to_update = df_update_data_to_bronze.count()
        
        if  rows_to_update == 0:
            # Logging if get no rows to update in minio landing
            logging.info(f"No new data to process for table {table_name_converted}")

        else:
            # Logging number of rows to update
            logging.info(f"Number of new rows to update for table {table_name_converted}: {rows_to_update}")
            
            # Adding a new column date related the load data
            df_with_update_date = func_file.add_data_last_update(df_update_data_to_bronze)
    
            # modifing the postgres tables for add a new column "month_key" to create a partition on the minIO landing based on modifieddate column
            df_with_month_partition = df_with_update_date.withColumn("month_key", date_format(df_with_update_date["modifieddate"], "yyyy-MM"))
            
            # Updating the dataframe on minIO landing
            logging.info(f"Updating table {table_name_converted}...")
            df_with_month_partition.write.format("parquet").mode("append").partitionBy("month_key").save(output_table_path)
            
            # Logging the sucessfully process
            logging.info(f"Table {table_name_converted} Sucessfully updated and saved in MinIO bronze on: {output_table_path}")

    except Exception as e:
        # Logging the Error
         logging.error(f"Error processing table {table_name}: {str(e)}")

# %%
if __name__ == "__main__":
    
    # Logging the Start process from ingestion
    logging.info("Starting incrmental load from MinIO landing to MinIO bronze...")

    spark = configure_spark()

    # landing path
    landing_path = config_file.data_lakehouse_path["landing"]
    
    # bronze path
    bronze_path = config_file.data_lakehouse_path["bronze"]

    # Creating a ThreadPool for divide all jobs among the workers and execute in parallel
    with ThreadPoolExecutor(max_workers=8) as executor:
        
        # Creating a list to Add all jobs into it
        futures = []
    
        # Getting each table was in the dictionary on config_file
        for table_name in config_file.tables_postgres_adventureworks.values():
            
            # convert the table name from postgres to name in minIO s3
            table_name_converted = func_file.convert_table_name(table_name)
    
            # Landing table path
            landing_table_path = f"{landing_path}{table_name_converted}"
            
            # Output table path
            bronze_table_path = f"{bronze_path}bronze_{table_name_converted}"

            # Instead of calling the function to execute it, call the function by passing it to the executor
            futures.append(executor.submit(process_table, spark, table_name, table_name_converted, landing_table_path, bronze_table_path))


        for future in as_completed(futures):
            try:
                # Where the all jobs is executing by the executors created with ThreadPoolExecutor
                future.result()

            except Execption as e:
                logging.error(f"Error in one of parallel taks: {str(e)}")

    
    # Logging the Incremental ingestion
    logging.info(f"Incremental ingestion to bronze layer completed!")
# Out:
# 2026-05-14 17:03:38,712 - INFO - Starting incrmental load from MinIO landing to MinIO bronze...
# 2026-05-14 17:03:46,052 - INFO - processing table sales_countryregioncurrency
# 2026-05-14 17:03:46,056 - INFO - Reading table from bronze layer
# 2026-05-14 17:03:46,054 - INFO - processing table sales_creditcard
# 2026-05-14 17:03:46,070 - INFO - Reading table from bronze layer
# 2026-05-14 17:03:46,060 - INFO - processing table sales_currencyrate
# 2026-05-14 17:03:46,081 - INFO - Reading table from bronze layer
# 2026-05-14 17:03:46,058 - INFO - processing table sales_currency
# 2026-05-14 17:03:46,072 - INFO - processing table sales_personcreditcard
# 2026-05-14 17:03:46,111 - INFO - Reading table from bronze layer
# 2026-05-14 17:03:46,086 - INFO - processing table sales_salesorderheader
# 2026-05-14 17:03:46,069 - INFO - processing table sales_customer
# 2026-05-14 17:03:46,135 - INFO - Reading table from bronze layer
# 2026-05-14 17:03:46,074 - INFO - processing table sales_salesorderdetail
# 2026-05-14 17:03:46,125 - INFO - Reading table from bronze layer
# 2026-05-14 17:03:46,099 - INFO - Reading table from bronze layer
# 2026-05-14 17:03:46,143 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:10,958 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:10,960 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:10,968 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:11,005 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:11,015 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:11,023 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:11,093 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:11,200 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:17,125 - INFO - No new data to process for table sales_creditcard
# 2026-05-14 17:05:17,129 - INFO - processing table sales_salesorderheadersalesreason
# 2026-05-14 17:05:17,127 - INFO - No new data to process for table sales_salesorderheader
# 2026-05-14 17:05:17,134 - INFO - processing table sales_salesperson
# 2026-05-14 17:05:17,137 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:17,132 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:17,323 - INFO - No new data to process for table sales_personcreditcard
# 2026-05-14 17:05:17,337 - INFO - processing table sales_salespersonquotahistory
# 2026-05-14 17:05:17,348 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:17,425 - INFO - No new data to process for table sales_currencyrate
# 2026-05-14 17:05:17,432 - INFO - processing table sales_salesreason
# 2026-05-14 17:05:17,436 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:17,447 - INFO - No new data to process for table sales_currency
# 2026-05-14 17:05:17,450 - INFO - processing table sales_salestaxrate
# 2026-05-14 17:05:17,452 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:17,486 - INFO - No new data to process for table sales_countryregioncurrency
# 2026-05-14 17:05:17,487 - INFO - processing table sales_salesterritory
# 2026-05-14 17:05:17,491 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:17,606 - INFO - No new data to process for table sales_customer
# 2026-05-14 17:05:17,624 - INFO - processing table sales_salesterritoryhistory
# 2026-05-14 17:05:17,630 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:17,683 - INFO - No new data to process for table sales_salesorderdetail
# 2026-05-14 17:05:17,688 - INFO - processing table sales_shoppingcartitem
# 2026-05-14 17:05:17,689 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:36,712 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:36,917 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:36,942 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:37,054 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:37,144 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:37,346 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:37,399 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:37,439 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:38,797 - INFO - No new data to process for table sales_salesterritory
# 2026-05-14 17:05:38,801 - INFO - processing table sales_specialoffer
# 2026-05-14 17:05:38,808 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:38,929 - INFO - No new data to process for table sales_shoppingcartitem
# 2026-05-14 17:05:38,934 - INFO - processing table sales_specialofferproduct
# 2026-05-14 17:05:38,936 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:38,943 - INFO - No new data to process for table sales_salestaxrate
# 2026-05-14 17:05:38,953 - INFO - processing table sales_store
# 2026-05-14 17:05:38,967 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:39,090 - INFO - No new data to process for table sales_salespersonquotahistory
# 2026-05-14 17:05:39,093 - INFO - processing table humanresources_employee
# 2026-05-14 17:05:39,099 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:39,113 - INFO - No new data to process for table sales_salesterritoryhistory
# 2026-05-14 17:05:39,119 - INFO - processing table humanresources_department
# 2026-05-14 17:05:39,130 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:39,563 - INFO - No new data to process for table sales_salesperson
# 2026-05-14 17:05:39,576 - INFO - processing table person_countryregion
# 2026-05-14 17:05:39,588 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:39,588 - INFO - No new data to process for table sales_salesreason
# 2026-05-14 17:05:39,610 - INFO - processing table person_person
# 2026-05-14 17:05:39,616 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:40,206 - INFO - No new data to process for table sales_salesorderheadersalesreason
# 2026-05-14 17:05:40,220 - INFO - processing table person_stateprovince
# 2026-05-14 17:05:40,228 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:54,509 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:54,515 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:54,546 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:54,550 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:54,740 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:54,793 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:54,835 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:54,842 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:05:55,896 - INFO - No new data to process for table humanresources_department
# 2026-05-14 17:05:55,897 - INFO - processing table person_address
# 2026-05-14 17:05:55,903 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:55,999 - INFO - No new data to process for table sales_specialofferproduct
# 2026-05-14 17:05:56,009 - INFO - processing table purchasing_shipmethod
# 2026-05-14 17:05:56,016 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:56,105 - INFO - No new data to process for table humanresources_employee
# 2026-05-14 17:05:56,111 - INFO - processing table production_product
# 2026-05-14 17:05:56,113 - INFO - Reading table from bronze layer
# 2026-05-14 17:05:56,277 - INFO - No new data to process for table person_countryregion
# 2026-05-14 17:05:56,278 - INFO - No new data to process for table sales_specialoffer
# 2026-05-14 17:05:56,370 - INFO - No new data to process for table sales_store
# 2026-05-14 17:05:56,371 - INFO - No new data to process for table person_stateprovince
# 2026-05-14 17:05:57,137 - INFO - No new data to process for table person_person
# 2026-05-14 17:06:02,084 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:06:02,309 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:06:02,431 - INFO - Reading table from landing layer and compare with new data
# 2026-05-14 17:06:03,169 - INFO - No new data to process for table production_product
# 2026-05-14 17:06:03,194 - INFO - No new data to process for table purchasing_shipmethod
# 2026-05-14 17:06:03,894 - INFO - No new data to process for table person_address
# 2026-05-14 17:06:03,895 - INFO - Closing down clientserver connection
# 2026-05-14 17:06:03,896 - INFO - Closing down clientserver connection
# 2026-05-14 17:06:03,898 - INFO - Closing down clientserver connection
# 2026-05-14 17:06:03,898 - INFO - Closing down clientserver connection
# 2026-05-14 17:06:03,900 - INFO - Closing down clientserver connection
# 2026-05-14 17:06:03,902 - INFO - Closing down clientserver connection
# 2026-05-14 17:06:03,902 - INFO - Closing down clientserver connection
# 2026-05-14 17:06:03,904 - INFO - Closing down clientserver connection
# 2026-05-14 17:06:03,912 - INFO - Incremental ingestion to bronze layer completed!

# %% [markdown]
# ## Stop session and clear cash from spark

# %%
spark.stop()
spark.catalog.clearCache()
